# %%
from github import Github
import time
from datetime import datetime
import os
ACCESS_Token = "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"
g = Github(ACCESS_Token)
print(g.get_user())
# Out:
# AuthenticatedUser(login=None)

# %%
end_time=time.time()
start_time = end_time-86400
for i in range(3):
        start_time_str = datetime.utcfromtimestamp(start_time).strftime('%Y-%m-%d')

        end_time_str = datetime.utcfromtimestamp(end_time).strftime('%Y-%m-%d')
        query = f"language:python created:{start_time_str}..{end_time_str}"
        print(query)
        end_time -= 86400
        start_time -= 86400
        
        result = g.search_repositories(query)
        print(result.totalCount)

        for repository in result:
                os.system(f"git clone {repository.clone_url} repos/{repository.owner.login}/{repository.name}")
# Out:
# language:python created:2024-05-04..2024-05-05
# 1000
# Cloning into 'repos/cloneofsimo/minRF'...
# Cloning into 'repos/lucidrains/mmdit'...
# Cloning into 'repos/garrydevpro/versatools'...
# Cloning into 'repos/Sandspeare/ida2llvm'...
# Cloning into 'repos/yoheinakajima/airtable_to_graph'...
# Cloning into 'repos/miloira/wxhook'...
# Cloning into 'repos/Kazuhito00/XFeat-Image-Matching-ONNX-Sample'...
# Cloning into 'repos/PerekhodovAnton/WebUIChatBotInference'...
# Cloning into 'repos/BSidesSF/badge-2024'...
# Cloning into 'repos/WorldObservationLog/AppleMusicDecrypt'...
# Cloning into 'repos/cynyr/ExcelLambdaDataVals'...
# Cloning into 'repos/ZiYuCai1984/YUPortal.Automation'...
# Cloning into 'repos/SpaceMercury/SatTeam'...
# Cloning into 'repos/WindVChen/VCO-AP'...
# Cloning into 'repos/yhuang0701/VLM-Attack'...
# Updating files: 100% (394/394), done.
# Cloning into 'repos/Scarlxrd211/Dm-all-bot'...
# Cloning into 'repos/KLordy/auto_publish_videos'...
# Cloning into 'repos/fabioalvarezns/chatbot-rag'...
# Cloning into 'repos/fabioalvarezns/voice-agent'...
# Cloning into 'repos/pratikG10/SONAR-Rock-vs-Mine-Prediction'...
# Cloning into 'repos/BarkSanson/hackupc24'...
# Cloning into 'repos/Whisper-Legendary/MicroSoft-UserName-Checker'...
# Cloning into 'repos/Youness-Cheradi/AES-Chiffrement-D-chiffrement-image'...
# Cloning into 'repos/Atharvkote/Online-Market-Place'...
# Cloning into 'repos/Enzofmlg/Znet'...
# Cloning into 'repos/sunnysavita10/chainlit'...
# Cloning into 'repos/esbenkc/unity-or-chaos'...
# Cloning into 'repos/haizelabs/thorn-in-haizestack'...
# Cloning into 'repos/laoyin/llm-fine-tuning'...
# Cloning into 'repos/MirzaSohaib-Baig/Phone-Tracker'...
# Cloning into 'repos/logan0601/Epi-Attention'...
# Cloning into 'repos/noclocks/emaildnscheck'...
# Cloning into 'repos/solid-marketings/coinmarketcap-auto-comment-bot'...
# Cloning into 'repos/Xueheng-Li/AskDocDirect'...
# Cloning into 'repos/zaid223r/chatapp'...
# Cloning into 'repos/Fibrous-Finance/limit-order-sdk-python'...
# Cloning into 'repos/zbuhrer/vectorsynapse'...
# Cloning into 'repos/oldkingOK/E-Spider'...
# Cloning into 'repos/Nyxoy201/discohooks'...
# Cloning into 'repos/priyamjha/19_Python_Projects'...
# Cloning into 'repos/theavgjojo/openai_api_tool_call_proxy'...
# Cloning into 'repos/amania-Jailbreak/gamdl-GUI'...
# Cloning into 'repos/nathangst/moni-groupeD'...
# Cloning into 'repos/BatuKaya8/ChatBot'...
# Cloning into 'repos/priyamjha/Python-Slot-Machine'...
# Cloning into 'repos/DSD-dev/DAXLER'...
# Cloning into 'repos/Shubham-Singla259/Blog-Generator-Web-App'...
# Cloning into 'repos/alexandernicholson/k8ss'...
# Cloning into 'repos/Wayan123/Reading-vehicle-license-plates-using-multimodal-gemini'...
# Cloning into 'repos/microsoft/dialop'...
# Cloning into 'repos/ZombieGeeK0/Cyphr'...
# Cloning into 'repos/Nazar1ky/epic-games-store-remove-all-friends'...
# Cloning into 'repos/Navezjt/ComfyUI-FaceChain'...
# Cloning into 'repos/James0618/MACD'...
# Cloning into 'repos/AsherJingkongChen/wgpu-native-installer'...
# Cloning into 'repos/danielssaugusto/voice_assistant'...
# Cloning into 'repos/Amzu-bzh/morpion-ai'...
# Cloning into 'repos/NikMehraDev/mychess'...
# Cloning into 'repos/SanderBetz/PRe-MSc_AE_Computational_Modelling'...
# Cloning into 'repos/riseadhikari/ml_deployment_fastAPI_AWS'...
# Cloning into 'repos/WhereIsMyMindDL/Reya'...
# Cloning into 'repos/RoundDoor/CheapGPT'...
# Cloning into 'repos/yinchi/histopath-bim-des'...
# Cloning into 'repos/thsrite/huawei_note_to_xiaomi_note'...
# Cloning into 'repos/ltcflip/etw-bypass'...
# Cloning into 'repos/ltcflip/amsi-bypass'...
# Cloning into 'repos/Manthanjajaj/Python---Library-management-Sysytem'...
# Cloning into 'repos/PavlaBla/python_czechitas'...
# Cloning into 'repos/Yulai202020/chess'...
# Cloning into 'repos/IsroilOrinboyev/Shopping-software'...
# Cloning into 'repos/Shantanutathe/shantanu1'...
# Cloning into 'repos/kwankoravich/LLM_Concrete'...
# Cloning into 'repos/AIAnytime/RAG-using-AWS-Bedrock-and-Azure-OpenAI'...
# Cloning into 'repos/gabitrombetta/RastrearEncomendas'...
# Cloning into 'repos/omiom33/file2link-om'...
# Cloning into 'repos/ClassyCoder1/Classy'...
# Cloning into 'repos/dayoonasanya/yfinance'...
# Cloning into 'repos/kevin3010/keyword-extractor-using-function-calling'...
# Cloning into 'repos/dkellerny/HMC-for-SV'...
# Cloning into 'repos/zhefeng687/data_science_apps'...
# Cloning into 'repos/ChenShuai00/-selenium-'...
# Cloning into 'repos/Squarezs/Leaf-LagSwitch'...
# Cloning into 'repos/lmProgramming/SelfLearningCars'...
# Cloning into 'repos/artemkaFismat/BV-2024'...
# Cloning into 'repos/Diablo408/GEOSNIFF-X'...
# Cloning into 'repos/BryceWG/Ultrasonic-range-measurement-vehicle'...
# Cloning into 'repos/ferhatyk95/how-to-cook'...
# Cloning into 'repos/SuzukaKing/Tokyo-Hot'...
# Cloning into 'repos/DucNgoVN/KVH'...
# Cloning into 'repos/ZianTT/sr_land'...
# Cloning into 'repos/AlexeiGH596/Python-Exercicios'...
# Cloning into 'repos/shuyanov/CLI-converterArwToJpeg'...
# Cloning into 'repos/blazfmyx/Aimmy-GPU-Test'...
# Cloning into 'repos/raffaforHTML/BrettbuakkkDDOSattack'...
# Cloning into 'repos/bdraco/aiohttp-fast-zlib'...
# Cloning into 'repos/Zxun2/github-actions'...
# Cloning into 'repos/marquitoxs/marcos-prueba-de-git-hub'...
# Cloning into 'repos/zaid223r/food-api-drf'...
# Cloning into 'repos/Daniil200707/RefactorFarmer'...
# Cloning into 'repos/xAmarnath/Valeri'...
# Cloning into 'repos/Thecode764/AI-Fetcher'...
# Cloning into 'repos/henakucuk/database'...
# Cloning into 'repos/ilterisYucel/l-cstaj-1'...
# Cloning into 'repos/fal-ai/fal-poe-bots'...
# Cloning into 'repos/VEGLOhouetchenouGABIN/Web-scraping-to-gain-company-insights'...
# Cloning into 'repos/Raazarya12/VJ-FILTER-BOT'...
# Cloning into 'repos/SowingG2333/machine_learning'...
# Cloning into 'repos/InSadNezz/Chest-Heist'...
# Cloning into 'repos/sdjnioudhff/MetaF2N-Pytorch'...
# Cloning into 'repos/Garvard-Agency/CVE-2024-20359-CiscoASA-FTD-exploit'...
# Cloning into 'repos/For-Anonymous-Use/CaWs-Segmentation-and-Detection'...
# Cloning into 'repos/Penrosian/MinCalc'...
# Cloning into 'repos/anesu398/Large-Language-Model'...
# Cloning into 'repos/BruceEckel/slug_line'...
# Cloning into 'repos/Jorge-Sol/Ai-webscraping-for-wellnessoasis'...
# Cloning into 'repos/Soumyajeet2004/Django_Login-System'...
# Cloning into 'repos/basudevgorai/indian_Flag'...
# Cloning into 'repos/Joker3993/MHG-Predictor'...
# Cloning into 'repos/shenmi175/SVHN-TianChi'...
# git-lfs filter-process: 1: git-lfs: not found
# fatal: the remote end hung up unexpectedly
# warning: Clone succeeded, but checkout failed.
# You can inspect what was checked out with 'git status'
# and retry with 'git restore --source=HEAD :/'
#
# Cloning into 'repos/Masterain98/CrunchbaseCompanyPeopleLister'...
# Cloning into 'repos/code-shm/Russian-Roulette'...
# Cloning into 'repos/graemeniedermayer/comfyui_patchfusion_depth'...
# Cloning into 'repos/A-Hameiri/Login-Program'...
# Cloning into 'repos/JusticePeter123/AKA-IvanDDoSS'...
# Cloning into 'repos/MuhummadIrtaza/Conways-game-of-life'...
# Cloning into 'repos/sunmou5565/WifiATT'...
# Cloning into 'repos/gabrielbaute/cli-siceu-unefa'...
# Cloning into 'repos/sokaydough/ribbon'...
# Cloning into 'repos/BaNNANNaa/ProgramingFolder-05-2024'...
# Cloning into 'repos/BlackRandomCraft/AezaProlong'...
# Cloning into 'repos/Navraj12/Student_Library'...
# Cloning into 'repos/1180779/db--thick-client__invoices'...
# Cloning into 'repos/bernardogoltz/machine-learning-cookbook'...
# Cloning into 'repos/glitchheadgit/tgbot_retinal_disease_classifier'...
# git-lfs filter-process: 1: git-lfs: not found
# fatal: the remote end hung up unexpectedly
# warning: Clone succeeded, but checkout failed.
# You can inspect what was checked out with 'git status'
# and retry with 'git restore --source=HEAD :/'
#
# Cloning into 'repos/Lazza/SourceRestorer'...
# Cloning into 'repos/mysterious029/Library-Management-System'...
# Cloning into 'repos/picklenchips/MARKET-MAKING-RL'...
# Cloning into 'repos/ddcw/pymysqlbinlog'...
# Cloning into 'repos/Mohamed9x60/SUBEX'...
# Cloning into 'repos/Leticia-maria/QVAE'...
# Cloning into 'repos/Hk-Hacker-Harsh/Converter'...
# Cloning into 'repos/Hiyoteam/awacoin-ng'...
# Cloning into 'repos/gustarkoz/test'...
# Cloning into 'repos/SreejanPersonal/Hugging-Chat-Reverse-Engineered-API'...
# Cloning into 'repos/ferhatyk95/eyestracking'...
# Cloning into 'repos/Neth066/Project-3'...
# Cloning into 'repos/DataRohit/Vendor-Management-System'...
# Cloning into 'repos/FununLtd/Fun-and-Co'...
# Cloning into 'repos/Spacenot4me/ArtEra-server-v2'...
# Cloning into 'repos/prajwal-M-P/rock-seizers-'...
# Cloning into 'repos/ChristopherGS/alice-and-bob-py'...
# Cloning into 'repos/FredrikBakken/lakefs-datafusion-py'...
# Cloning into 'repos/noejunior792/desafios-trilha-python-dio'...
# Cloning into 'repos/GustavoSchiavinato/sistema_bancario_v3_modelado_em_poo_python'...
# Cloning into 'repos/ComputerWare/shh-browser'...
# Cloning into 'repos/jbeduze/template'...
# Cloning into 'repos/MUGISHA-Pascal/python'...
# Cloning into 'repos/muyaniker90/100Daysofcode'...
# Cloning into 'repos/Millecenttrantequatre2/Unlink-fiveM'...
# Cloning into 'repos/Mattral/Kolmogorov-Arnold-Networks'...
# Cloning into 'repos/LaunchPlatform/beanhub-extract'...
# Cloning into 'repos/AbsHp/Python-Projects'...
# Cloning into 'repos/Vidyanandpasunuri/MILsummerapp'...
# Cloning into 'repos/paralin/claude'...
# Cloning into 'repos/noPROst2/pythonEgitimi'...
# Cloning into 'repos/Akhil-Krishna/DigiKerala'...
# Cloning into 'repos/jloh02/capt-laundry-bot'...
# Cloning into 'repos/zaid223r/todolist'...
# Cloning into 'repos/Amadeo-Frontend/Python__API-SQL-DOCKER'...
# Cloning into 'repos/RiyaAggarwal3008/campus_cruisers'...
# Cloning into 'repos/Kashman1122/Fire'...
# Cloning into 'repos/bhuvi-ai/Chrome-Dictionary-Extension'...
# Cloning into 'repos/JoseTorquato/algorithm'...
# Cloning into 'repos/truelockmc/Gmail-Phishing-Site'...
# Cloning into 'repos/AmeShajid/Mutli-Clipboard'...
# Cloning into 'repos/henryqbonilla/StudyBud'...
# Cloning into 'repos/Sudhanshu88/Tikamghar-Admission'...
# Cloning into 'repos/Vaibhav-kesarwani/Flappy-bird-game'...
# Cloning into 'repos/ferhatyk95/gazetracking'...
# Cloning into 'repos/DawidPietrykowski/llm-converter'...
# Cloning into 'repos/frereit/syscalls.win'...
# Cloning into 'repos/AlexisSerano/Jeu-de-la-vie'...
# Cloning into 'repos/psyduck890/DJ_TimeTracker'...
# Cloning into 'repos/mrsidabukke/python-oop'...
# Cloning into 'repos/tue09/Kernel-Zoo'...
# Cloning into 'repos/bufo333/python-dns-exfiltration-client-server'...
# Cloning into 'repos/Rishit-katiyar/Aerospace_Task_and_Motion_Planning'...
# Cloning into 'repos/abdul97233/File-Sharing-Bot'...
# Cloning into 'repos/Betoneiro/Python-Projects'...
# Cloning into 'repos/iurii-umnov/it-storage'...
# Cloning into 'repos/defnecirci/MatSciQA_RAG'...
# Cloning into 'repos/DURBIJ/File_Uploading_of_All_types'...
# Cloning into 'repos/YINYIPENG-EN/yolov5_hand_pose'...
# Cloning into 'repos/basudevgorai/animated_ganesh'...
# Cloning into 'repos/LumpyName/laberinto_py_Gg'...
# Cloning into 'repos/priyamjha/Aim_Trainer'...
# Cloning into 'repos/andrewsuadnya/PROJECT-4-SIB-DigitalSkola'...
# Cloning into 'repos/Nekolial/BruteSociety'...
# Cloning into 'repos/parasharharsh16/Deep-Learning-Ops'...
# Cloning into 'repos/ShayMarks/walla_scraper'...
# Cloning into 'repos/NPS809/PyConsoleEngine'...
# Cloning into 'repos/Solrikk/DataDresser'...
# Cloning into 'repos/bharath-viz/MLOPS'...
# Cloning into 'repos/Ledgerbiggg/duwi_smart_sdk'...
# Cloning into 'repos/raeliz/to_do_app'...
# Cloning into 'repos/ItsTeraBytes/Lethal-MC-Resourcepack'...
# Cloning into 'repos/rgough5/tom'...
# Cloning into 'repos/bj-wang-wei/NiceApp'...
# Cloning into 'repos/Chinmayee2524/chinmayee2524'...
# Cloning into 'repos/Damla-keklik/proje2'...
# Cloning into 'repos/Jalithc/tensorflow_checkup_c'...
# Cloning into 'repos/kunalbandale/StyleMate-Fashion-Recommender-System'...
# git-lfs filter-process: 1: git-lfs: not found
# fatal: the remote end hung up unexpectedly
# warning: Clone succeeded, but checkout failed.
# You can inspect what was checked out with 'git status'
# and retry with 'git restore --source=HEAD :/'
#
# Cloning into 'repos/Browniesauce/Youtube-Vidoe-Downloader'...
# Cloning into 'repos/SuleymanSade/Mp4-to-Mp3-Converter'...
# Cloning into 'repos/eightBEC/unsloth-docker'...
# Cloning into 'repos/fengsxy/gpt_batch'...
# Cloning into 'repos/cjz-wr/micropython_oled_display'...
# Cloning into 'repos/mohitbooraget/Restrictedsaver'...
# Cloning into 'repos/Jalithc/add_func_in_tf'...
# Cloning into 'repos/AnderVarela/HackUPC'...
# Updating files: 100% (46762/46762), done.
# Cloning into 'repos/AkankshaJojy/Detection-of-Counterfiet-Shoes'...
# Cloning into 'repos/swanand203/Simulate-Elliptical-Orbit-Using-Pygame'...
# Cloning into 'repos/ferhatyk95/pelletfuel'...
# Cloning into 'repos/Netesfiu/EON-SPOOKER'...
# Cloning into 'repos/linhaowei1/MolRetrieval'...
# Cloning into 'repos/daixiangau/DEAL_2022'...
# Cloning into 'repos/kstanghere/GenderCARE-ccs24'...
# Cloning into 'repos/Effece/Turing'...
# Cloning into 'repos/luisa-alr/TimeSeries-Implementation'...
# Cloning into 'repos/Whisper-Legendary/Yahoo-Check'...
# Cloning into 'repos/evgfilim1/mafia-companion-api'...
# Cloning into 'repos/Arti-kuciuk/Sign-language'...
# Cloning into 'repos/Niko13teen/WebCommentAnalyzer'...
# Cloning into 'repos/CHERWING/CHERWIN_OCR'...
# Cloning into 'repos/Rafalima22/inova-escola'...
# Cloning into 'repos/prestino210/battleship-py'...
# Cloning into 'repos/maurokeindeveloper/trueque_tools'...
# Cloning into 'repos/ManjiPY/qrcode-py'...
# Cloning into 'repos/lslucasO/controle-de-estoque'...
# Cloning into 'repos/Roud-Roud-Agency/CVE-2024-26304-RCE-exploits'...
# Cloning into 'repos/Shubham-C12/Azure-ComputerVision-TextExtractor'...
# Cloning into 'repos/kroussen/online_store-django'...
# Cloning into 'repos/NPS809/PyConsole'...
# Cloning into 'repos/Doriasamp/DawgsML'...
# Cloning into 'repos/AUBAI-ALKHABBAZ/Mapping_TIAGo_lite_Webots'...
# Cloning into 'repos/iurii-umnov/async-parser'...
# Cloning into 'repos/manavspg4/Quant-Trading-Strategies'...
# Cloning into 'repos/Mehrafarin77/TCP-chatroom-with-python'...
# Cloning into 'repos/Junjie529/AWS-election'...
# Cloning into 'repos/saikothouse/Temp-Mail-Bot'...
# Cloning into 'repos/Blane187/Blane-RVC-Main'...
# Cloning into 'repos/Shubham1965/rl-projects'...
# Cloning into 'repos/Sippaphat/Kiddee-TableQA'...
# Cloning into 'repos/Gustavo127400/Python'...
# Cloning into 'repos/halovina/fastapi-tutorial'...
# Cloning into 'repos/ShubhoEditx/SohiniMusicXPro'...
# Cloning into 'repos/fitri-hy/auto-generate-project-python'...
# Cloning into 'repos/wert1xxx1/Mafia-Discord-bot'...
# Cloning into 'repos/iamruth143/InternPE'...
# Cloning into 'repos/jnotsknab/PokemonShinyBot'...
# Cloning into 'repos/Hrishikesh19032004/DemandForecasting'...
# Cloning into 'repos/MemerGamer/TrafficSignRecognitionCNN'...
# Cloning into 'repos/hnilitskyi/instagram_scraper'...
# Cloning into 'repos/seanpm2001/LSRT'...
# Cloning into 'repos/PariBainsla/SnakeGame'...
# Cloning into 'repos/Junjie529/aws-server-zap'...
# Cloning into 'repos/Frikallo/x-ops'...
# Cloning into 'repos/Nextcaffe/game_numbers'...
# Cloning into 'repos/kagura7799/parser-bot'...
# Cloning into 'repos/sksahid24449/Social-Network-Dataset-Analysis-for-Centrality-Measurement'...
# Cloning into 'repos/Narvasiddhartha/Disaster-Tweet-Classification'...
# Updating files: 100% (7469/7469), done.
# Cloning into 'repos/fsaza/Crypot-Tools'...
# Cloning into 'repos/sqltechnology/Sqltech'...
# Cloning into 'repos/LucasLisboaDev/CalculatorGUI_Python'...
# Cloning into 'repos/ferhatyk95/emotional-state-analysis-from-voice'...
# Cloning into 'repos/NanDONG2002/20319111-COMP3065-CW'...
# error: 6411 bytes of body are still expected
# fetch-pack: unexpected disconnect while reading sideband packet
# fatal: early EOF
# fatal: fetch-pack: invalid index-pack output
# Cloning into 'repos/quinn-sasha/personal_finance_app'...
# Cloning into 'repos/akki697222/SoundBoard-V1'...
# Cloning into 'repos/LevyShaked/Assignments_rep'...
# Cloning into 'repos/Matvei55/CityHeroes_-git'...
# Cloning into 'repos/imprasukjain/Code-Pilot'...
# Cloning into 'repos/brian419/AlgorithmVisualizations'...
# Cloning into 'repos/DuckDuckStudio/Just-No-xxx'...
# Cloning into 'repos/arachnocid/Cryptocurrency-Prediction-Model'...
# Cloning into 'repos/devinci-it/devinci_rc'...
# Cloning into 'repos/Harshith1234567/webscraper-using-GPT3.5-langchain-chromaDB'...
# Cloning into 'repos/EthanInnit28/NukPack-Tool-Discord-'...
# Cloning into 'repos/Camilly-Alveess/Basic-Natural-Language-Processing'...
# Cloning into 'repos/Enigma-Soul/EnigmaSoul_Houl'...
# Cloning into 'repos/XingLanGo/Format_Headers_Dict'...
# Cloning into 'repos/ElGreKost/Redundant-Manipulator-Ros'...
# Cloning into 'repos/i-umairkhan/vid2sound'...
# Cloning into 'repos/swanand203/Stimulate-bouncing-game-using-Pygame'...
# Cloning into 'repos/BuGmAN12345/book-crawlers'...
# Cloning into 'repos/ufodia/bitcoin_address_generator'...
# Cloning into 'repos/vishwamm/webapp_objectdetection'...
# Cloning into 'repos/vishwamm/webapp_facedetection'...
# Cloning into 'repos/Sayandeepmaity/neurogest'...
# Cloning into 'repos/YuvrajSinghSran/Chat-CSV-Using-Langchain-and-OpenAI'...
# Cloning into 'repos/hatprof/tg-mass-dm'...
# Cloning into 'repos/jggomez/gemini-workshop'...
# Cloning into 'repos/CeyLabs-Foundation/fin-tracker-backend'...
# Cloning into 'repos/brahim77777/Simplex_method_with_php_and_python'...
# Cloning into 'repos/VilchisV/metodos'...
# Cloning into 'repos/Jalithc/check_if_updated'...
# Cloning into 'repos/WojtekCodesToday/rgb-hex-renderer'...
# Cloning into 'repos/ssapna64/BANKINGPROJECT'...
# Cloning into 'repos/Amaan9136/vision-xray'...
# Cloning into 'repos/AndB0ndar/django_mongodb_template'...
# Cloning into 'repos/pyungjong0314/Embedding-Using-Korean'...
# Cloning into 'repos/tolm1/-GUI-'...
# Cloning into 'repos/soglopr/TetrisT'...
# Cloning into 'repos/qaz-del/inter_demo'...
# Cloning into 'repos/Dashstrom/pixelize'...
# Cloning into 'repos/engineerjoe440/phasors'...
# Cloning into 'repos/silky-modi22/Video-Transcribe-Summarizer'...
# Cloning into 'repos/AppleBoiy/FlaskPG-dev'...
# Cloning into 'repos/Pawan-079/Movies-Recommendation-System-End-to-end'...
# git-lfs filter-process: 1: git-lfs: not found
# fatal: the remote end hung up unexpectedly
# warning: Clone succeeded, but checkout failed.
# You can inspect what was checked out with 'git status'
# and retry with 'git restore --source=HEAD :/'
#
# Cloning into 'repos/KJ-Script/Sniffer'...
# Cloning into 'repos/Amadeo-Frontend/Python__TDD-project'...
# Cloning into 'repos/Tarodictrl/GenshinWishHistory'...
# Cloning into 'repos/bhart17/robohack24'...
# Cloning into 'repos/josnin/llama-medical'...
# Cloning into 'repos/younesbram/chef-roast-me'...
# Cloning into 'repos/zxuuuustupid/cifar10'...
# Cloning into 'repos/Ashleshk/Realtime-Data-Streaming-Data-Engineering-Project'...
# Cloning into 'repos/handycandy279/rest-apis-project'...
# Cloning into 'repos/Aman-R-8103/Python_Project'...
# Cloning into 'repos/nompar12/EntregableNT_AlejandroVillaChica'...
# Cloning into 'repos/franciscofujiki/002-streamlit-blog-post-generator'...
# Cloning into 'repos/gheacs/RPlidar'...
# Cloning into 'repos/ahmedElmersawy/Email-Spam-Filter'...
# Cloning into 'repos/williamwei2025/Time-Pressure-on-Chess'...
# Cloning into 'repos/djhi12/finance-tracker'...
# Cloning into 'repos/prannav17/LP2'...
# Cloning into 'repos/aminbista66/chat-room'...
# Cloning into 'repos/chung011/2024_113_0427'...
# Cloning into 'repos/Anindya-Kumar-Patro/FastAPI-tutorial'...
# Cloning into 'repos/shivamkumar12345/employee_management_system'...
# Cloning into 'repos/iisabelacf/e-commerc_api'...
# Cloning into 'repos/dhanushgubba/student-counselling'...
# Cloning into 'repos/naistrai/sandowichi'...
# Cloning into 'repos/ProStrike2448/pyside6-image-editor'...
# Cloning into 'repos/Mridul-2003/Object_Detection-DNN-'...
# Cloning into 'repos/flyingGH/Sphere_SFM_Scripts'...
# Cloning into 'repos/Arkan7869/M3L2'...
# Cloning into 'repos/adityabob/e-commerce-app'...
# Cloning into 'repos/towardsinnovationlab/AI_Personal_Assistant'...
# Cloning into 'repos/eoan-ermine/clicker'...
# Cloning into 'repos/MDshihab10209/hack10'...
# Cloning into 'repos/EDIKA8/D82-HW-line---377'...
# Cloning into 'repos/hayatohanaoka/tweet_api'...
# Cloning into 'repos/Jaman0056/OLD'...
# Cloning into 'repos/grisuno/adonay'...
# Cloning into 'repos/JANUS2004/BookEaseAPI'...
# Cloning into 'repos/JayChao0331/EEC_289A-HW1'...
# Cloning into 'repos/NazilNA/Hospital_appoinmenet'...
# Cloning into 'repos/AntonioGN20/hill_climbing2'...
# Cloning into 'repos/Shalom4931/10laba'...
# Cloning into 'repos/kawserraihan/Django-React-Demo'...
# Cloning into 'repos/dimqaa50011/test_userbot'...
# Cloning into 'repos/JoseAT0912/Generados-contrase-as'...
# Cloning into 'repos/Hanvitha-51/NER_Telugu'...
# Cloning into 'repos/sunnyseed/split_audio'...
# Cloning into 'repos/aasgary/cibc'...
# Cloning into 'repos/rianmz-genz/prak7-ml'...
# Cloning into 'repos/dsempresa/python_provas'...
# Cloning into 'repos/realTristan/racecar-tracking'...
# Cloning into 'repos/AlexIvanov12/Python'...
# Cloning into 'repos/Patch-Code-Prosperity/Stock-Corporate-Action-Data'...
# Cloning into 'repos/josehac01/Publicacion01'...
# Cloning into 'repos/sarda-devesh/cs744-data-generator'...
# Cloning into 'repos/DavidCisneros563/Enfoque-B-squeda-P2-DACD-21110381'...
# Cloning into 'repos/rikudouIO/just-a-parser'...
# Cloning into 'repos/GenAjay/Digi_Ag_Assignment'...
# Cloning into 'repos/vrylskyj/goit-algo-hw-05'...
# Cloning into 'repos/villagehacker/object-detection'...
# Cloning into 'repos/ashamerine/my-first-blog'...
# Cloning into 'repos/stitch-1/my-first-blog'...
# Cloning into 'repos/pandu-hekar/cloud-2'...
# Cloning into 'repos/devikrishnaofficial/number_guess'...
# Cloning into 'repos/angelesplazadelosreyes/serenity_scheduler'...
# Cloning into 'repos/codewithcats/hello-llamaindex-py'...
# Cloning into 'repos/Thiago-Nassiben-Freri/shopping-list-py'...
# Cloning into 'repos/RishiKumar1917/Python-project'...
# Cloning into 'repos/tranluongnguyen/CS685_final_project'...
# Cloning into 'repos/RiemannIntegrable/Curso-entornos-pip-Platzi'...
# Cloning into 'repos/OrangeSoda6/my-first-blog'...
# Cloning into 'repos/Janet16180/Azul_IA_analysis'...
# Cloning into 'repos/MikeAguila41/red_neuronal_gps'...
# Cloning into 'repos/asliddinabijonov/Todo_backend'...
# Cloning into 'repos/seunboy1/Testing'...
# Cloning into 'repos/Asadbek-1101/3-loyiha'...
# Cloning into 'repos/amaterusdb/amaterus_announce_image_downloader'...
# Cloning into 'repos/Brul1/BOT'...
# Cloning into 'repos/jaingaurav126/Kivymd-Snapchat-like-app'...
# Updating files: 100% (6817/6817), done.
# Cloning into 'repos/gnanendranaidun/app_library'...
# Cloning into 'repos/Artur332/Dz6'...
# Cloning into 'repos/teja0006/iris-prediction-with-streamlit'...
# Cloning into 'repos/hibaaltaee/todo'...
# Cloning into 'repos/ZaharPavlikov/workk'...
# Cloning into 'repos/pradeepamuthusamy/password'...
# Cloning into 'repos/snehalnp/weather-sdk'...
# Cloning into 'repos/Niloy33/Final_Exam'...
# Cloning into 'repos/Nameer-nasar/todo'...
# Cloning into 'repos/DmitriyGusarov228/ping_pong'...
# Cloning into 'repos/shasss447/LLMEval'...
# Cloning into 'repos/Mohammednamara/Namra'...
# Cloning into 'repos/joshuadongon22/ACT2'...
# Cloning into 'repos/JacksonP013/Salary_prediction'...
# Cloning into 'repos/AasthaSharma-git/Class128Modified'...
# Cloning into 'repos/emeleonufavour/http-server'...
# Cloning into 'repos/vikyw89/autogen-playground'...
# Cloning into 'repos/HeathenH/3002-project'...
# Cloning into 'repos/Faith-vaati/AirBnB_clone_v4'...
# Cloning into 'repos/Faith-vaati/AirBnB_clone_v3'...
# Cloning into 'repos/angelakeinth/ipat2av2'...
# Cloning into 'repos/iz-smith/dynamic-prog-prac'...
# Cloning into 'repos/vishakhasaxena/ai_expense_tracker'...
# Cloning into 'repos/444B/NibbleNotes'...
# Cloning into 'repos/yonacraft1234/KivyApps'...
# Cloning into 'repos/GGuerra-33/Weather-app'...
# Cloning into 'repos/ashoka11/Dark-web-crawler'...
# Cloning into 'repos/sujalkyal/ml---projects'...
# Cloning into 'repos/MrDoge5310/mobileApp'...
# Cloning into 'repos/samarthpandeydev/langchain-groq-chainlit'...
# Cloning into 'repos/nshutidavid/PDF-Password-Protector'...
# Cloning into 'repos/pyadrus/xml_converter'...
# Cloning into 'repos/Leonardo-Henao/TranslateXML'...
# Cloning into 'repos/Patricio-14/Gestionador-de-contrase-as'...
# Cloning into 'repos/Dzakiamriz22/Implementasi-Sistem-Persamaan-Linear'...
# Cloning into 'repos/Vinod-756/SARVER-'...
# Cloning into 'repos/Pav-mis/CPP_analysis'...
# Cloning into 'repos/GbAlteri/Harmonic-Oscillator-Python-Class'...
# Cloning into 'repos/ottdc6030/bad-speed-checkers'...
# Cloning into 'repos/jnognet/agenda_backup'...
# Cloning into 'repos/thingsiplay/retroarch-import-playlist'...
# Cloning into 'repos/AKKI0511/Natural-Language-Parser'...
# Cloning into 'repos/edalgi/company-web'...
# Cloning into 'repos/aooolykung/articu_bot'...
# Cloning into 'repos/longtranv/celery_exercise'...
# Cloning into 'repos/ynsrc/python-simple-rest-api'...
# Cloning into 'repos/RobotTraders/LiveTradingBots'...
# Cloning into 'repos/mas2770/sorted_with_LRmate200id-7L'...
# Cloning into 'repos/maskaravivek/llamaindex_question_answer_circleci'...
# Cloning into 'repos/WebDevCatalog/gev_zibil'...
# Cloning into 'repos/liohchina/gearbox_lstm'...
# Cloning into 'repos/ikubaysan/reesonite-websocket-to-image'...
# Cloning into 'repos/rosacry/chrigsStock'...
# Cloning into 'repos/ZwiReKsyno/Disable_UPS_beeper_USB_in_Synology_NAS'...
# Cloning into 'repos/Harikrishna351/codebuild_lambda_updating'...
# Cloning into 'repos/chandrikaperala/assignment2'...
# Cloning into 'repos/Om-Deshamudre/Anomaly-Detection'...
# Cloning into 'repos/SatchalPatil/CollegePredictorBot'...
# Cloning into 'repos/Lthecoders/017_100day'...
# Cloning into 'repos/VIPULCODEX/TRAFFIC_SIMULATION'...
# Cloning into 'repos/MaxiSoriano70/IITA-TP6-FLASK-CRUD'...
# Cloning into 'repos/baicaizhale/File-classifier'...
# Cloning into 'repos/bunyaminkaplan/projects_blog'...
# Cloning into 'repos/dimok34/YandexPlus'...
# Cloning into 'repos/alexrg91/pruebas'...
# Cloning into 'repos/nethsuka/GUI_Student_Data_Collector'...
# Cloning into 'repos/spl1t1kszzz/nn_lab_1'...
# Cloning into 'repos/kallipro/test2'...
# Cloning into 'repos/aloba-james/nodh-demo4-new'...
# Cloning into 'repos/Hemanthviky/Text-Summarizer-using-llm-langchain'...
# Cloning into 'repos/silaerd/Aufgabe_8_Objektorientierung'...
# Cloning into 'repos/TTForGH/HexPlane-s3im'...
# Cloning into 'repos/marko1616/mahjong_DRL'...
# Cloning into 'repos/ApprenticeofEnder/secure-logging'...
# Cloning into 'repos/pbbrausch/Stock-Simulator'...
# Cloning into 'repos/aryan-02/engl2303-script-word-counter'...
# Cloning into 'repos/Jillian2003/Notes-DB_Project'...
# Cloning into 'repos/ROKO2910/Django'...
# Cloning into 'repos/Regihnaldo/Cambjar-contrase-a'...
# Cloning into 'repos/nthileepan/domo-repo'...
# Cloning into 'repos/JosueLm7/LIBROS'...
# Cloning into 'repos/Acedwdev/apirest'...
# Cloning into 'repos/CaioMelo204/django-rest-framework-simplified'...
# Cloning into 'repos/thet12323342234/ghgi_tool_updates'...
# Cloning into 'repos/franciscofujiki/003-streamlit-split-and-summarize'...
# Cloning into 'repos/guzmanjose-cloud/least-squares-method'...
# Cloning into 'repos/mrpodcaster/telegram-bot'...
# Cloning into 'repos/JesusGomezDev/yt_downloader_back'...
# Cloning into 'repos/KathleenCode/quiz'...
# Cloning into 'repos/Hermigod007/Techplement'...
# Cloning into 'repos/gabrielzv1233/JewFuss-XT'...
# Cloning into 'repos/tantowish/claude-test'...
# Cloning into 'repos/Iihtisham12/demo'...
# Cloning into 'repos/Yasoja44/trainToTestLora'...
# Cloning into 'repos/xukonxe/Gomoku-in-10Rooms'...
# Cloning into 'repos/sunnydsouza/MysticVault'...
# Cloning into 'repos/RamaManohar5/advanced_python_concepts'...
# Cloning into 'repos/aaftab05/Virtual-Ticketing-System'...
# Cloning into 'repos/pabloperezmartinez/lab2-template'...
# Cloning into 'repos/jiyoung10/python_auto_study'...
# Cloning into 'repos/cley9/Enviroment-in-python-with-version-diferent'...
# Cloning into 'repos/Danial14/basic'...
# Cloning into 'repos/pbwbb/THM'...
# Cloning into 'repos/Akasaka-I/Malimg-CNN-Practicing'...
# Cloning into 'repos/ManikantaThummalapudi12/Identification-of-lung-deteriorated-by-irreversible-pulmonary-fibrosis-using-deep-neural-networks'...
# Cloning into 'repos/mumpskin/my-first-blog'...
# Cloning into 'repos/nidehaihai/test4'...
# Cloning into 'repos/EASTghr/1'...
# Cloning into 'repos/static-web-apps-testing-org/swa0166d514e3084a1f8d07e81f41e0eef5'...
# Cloning into 'repos/bunty0703/date_time'...
# Cloning into 'repos/AkzhigitovRifat/PILAB'...
# Cloning into 'repos/bigmasy/goit-algo-hw-04'...
# Cloning into 'repos/ToushikBanik123/Paper_code'...
# Cloning into 'repos/samudra-perera/TheDailyStoic'...
# fatal: destination path 'repos/samudra-perera/TheDailyStoic' already exists and is not an empty directory.
# Cloning into 'repos/duncanodhis/Streamlit-with-fine-tuned-llama-2-using-qlora-and-peft'...
# Cloning into 'repos/Sheldon-CodeIt/django-production-apis'...
# Cloning into 'repos/Sneha4513/spam-classifier.github.io.'...
# Cloning into 'repos/ShayC0derBui/testBinance'...
# Cloning into 'repos/Amarjitkuma/hello-streamlit'...
# Cloning into 'repos/Ridwan805/Problem-Solving-of-Hackerrank'...
# Cloning into 'repos/rensl88/monthly-costs'...
# Cloning into 'repos/mayank31398/gym-text'...
# Cloning into 'repos/Sohilalashien/ASWE'...
# Cloning into 'repos/enzoschitini/deploys'...
# Cloning into 'repos/isuruK2003/heat_index_calculator'...
# Cloning into 'repos/glnnluciano/calculator'...
# Cloning into 'repos/DimaFlyutich/ping-pong'...
# Cloning into 'repos/Indar17/PRODIGY_CS_01'...
# Cloning into 'repos/JustusSu/FluProp-Erweiterung'...
# Cloning into 'repos/jojocoder28/Mutual_Fund_Chatbot'...
# Cloning into 'repos/mohmedate/mojmj'...
# Cloning into 'repos/pratiksha-shikhare/Blog-Project'...
# Cloning into 'repos/TSAI-CHIANG/Face_detect'...
# Cloning into 'repos/Siddique-07/Calculator-using-python'...
# Cloning into 'repos/hdsjiw/Algorithm'...
# Cloning into 'repos/COCO51raline/MOI'...
# Cloning into 'repos/luizh3/docker'...
# Cloning into 'repos/PrathamChhabra04/VoiceCraft'...
# Cloning into 'repos/tylertzm/chatpdf-powered-by-llama3'...
# Cloning into 'repos/Ramani-530/SLASH-MARK-basic-project-task-1'...
# Cloning into 'repos/Bunnisher/Son-s-Dolch'...
# Cloning into 'repos/rivajain/videosumm'...
# Cloning into 'repos/RayOgeto/Python-OOP'...
# Cloning into 'repos/Lester1989/ContainerJedi'...
# Cloning into 'repos/Igorlvi/Adding-in-column-Python'...
# Cloning into 'repos/Triad01/AirBnB_clone_v2'...
# Cloning into 'repos/alexbogatir2019/d3.1-django'...
# Cloning into 'repos/MU3AHTROP/NETS4'...
# Cloning into 'repos/DushyanthvarmaK/sample'...
# Cloning into 'repos/Dim1468/Team-project-VKinder'...
# Cloning into 'repos/gprithvi369/Dynamic-Real-Time-Data-Fusion-and-Insight-Engine'...
# Cloning into 'repos/siddheshkadam1640/findinglanes'...
# Cloning into 'repos/DorotaPilinska/PythonInFinance'...
# Cloning into 'repos/satvik314/resume-parser'...
# Cloning into 'repos/simonthecreator/process-model-repair'...
# Cloning into 'repos/ElyasYid/AirBnB_clone_v4'...
# Cloning into 'repos/ehab-al-Mawardi/AirBnB_clone_v4'...
# Cloning into 'repos/Jeriel86/chatbot-pytorch'...
# Cloning into 'repos/averyfreeman/GH_collab'...
# Cloning into 'repos/intidharr/Taquin'...
# Cloning into 'repos/aarshpatel1/QuizGameOOP'...
# Cloning into 'repos/xLeoArizax/tablas.'...
# Cloning into 'repos/ParthBehl1/asphalt_controller'...
# Cloning into 'repos/94dj/crm'...
# Cloning into 'repos/ivanliyangfan/rembg_simple'...
# Cloning into 'repos/SergeyKalutsky/meme_game'...
# Cloning into 'repos/TripathiHemendra/Python'...
# Cloning into 'repos/rgaveiga/optionlab_old'...
# Cloning into 'repos/smit0086/CloudComputingAssignments'...
# Cloning into 'repos/arihazaahira/linearregressionmodel'...
# Cloning into 'repos/DaniilKlyach/notes'...
# Cloning into 'repos/muztishini/Personal_financial_wallet'...
# Cloning into 'repos/AshishKumarBihar/DNA-Project'...
# Cloning into 'repos/siyona1/leetcode'...
# Cloning into 'repos/Umit22/Cnn-Modeller'...
# Cloning into 'repos/eliza0000/Cars'...
# Cloning into 'repos/isfn00/readingFrameScanner'...
# Cloning into 'repos/MINAADELMARKOS/ETL-Dockerized-Data-Pipeline'...
# Cloning into 'repos/Godsonoheneba/digital_africa_git_ex1'...
# Cloning into 'repos/Jayson-Gonzalez/Python_Dept-Instructor_Sqlite'...
# Cloning into 'repos/GenioustaWiz/attendance'...
# Cloning into 'repos/beliybear/googlesheets_bot'...
# Cloning into 'repos/Clarsch/investment_analyzer'...
# Cloning into 'repos/coganka/algorithms-data-structures-problems'...
# Cloning into 'repos/AchilleFomo/pythonProject1'...
# Cloning into 'repos/AukeSonneveld/zwerfinator'...
# Cloning into 'repos/PRITHVI01234/streamlit1.34'...
# Cloning into 'repos/ahmadalwareh/mcs_stock_project'...
# Cloning into 'repos/G3rgosz/oop_python_project'...
# Cloning into 'repos/N-Jia-Wen/Day-84-Portfolio-Project-Tic-Tac-Toe'...
# Cloning into 'repos/Sindhia-raj96/weather-app'...
# Cloning into 'repos/lucasdiasp/python_script_study'...
# Cloning into 'repos/ahsodud/Python-database'...
# Cloning into 'repos/Parthiban318/MDE85-Project-2-PhonePe-Data-Visualization'...
# Cloning into 'repos/jfinfocesde/streamlit_pi2'...
# Cloning into 'repos/simonhansedasi/pyopoly'...
# Cloning into 'repos/KageRyo-Lab/EasyCalc'...
# Cloning into 'repos/sarvarsangilov/aiogram3-template'...
# Cloning into 'repos/ShraavaniTople/MedSegTumor-Deep-Learning-for-Medical-Image-Segmentation'...
# Cloning into 'repos/Awxipyz/112'...
# Cloning into 'repos/ahmedheakl/fish-counting'...
# Cloning into 'repos/f1nn43/pgzeroGame'...
# Cloning into 'repos/umidrza/py-tasks2'...
# Cloning into 'repos/fanqingsong/ollama-docker'...
# Cloning into 'repos/matefriki/ml2-assignment2'...
# Cloning into 'repos/itsmeastonishingmanan/Breakout-Ball-game'...
# Cloning into 'repos/lochan28/school-project'...
# Cloning into 'repos/Vignesh2712/403bypasser'...
# Cloning into 'repos/aliya-haris/Company-API'...
# Cloning into 'repos/youngh585/bootcamp'...
# Cloning into 'repos/Karyqqe/japannese-blood'...
# Cloning into 'repos/Walapalam/intellihack_raccoons_task2'...
# Cloning into 'repos/PavelShaura/wallet_cli_app'...
# Cloning into 'repos/Cointreouz/au-adm'...
# Cloning into 'repos/aleks4n/ML_python'...
# Cloning into 'repos/LeonardoBaptista-dev/i_am_surfer'...
# Cloning into 'repos/Ridham-Bheda/myfirstbinder'...
# Cloning into 'repos/kmashfaque/recursion'...
# Cloning into 'repos/404-UnknownUsername/BCDNet'...
# Cloning into 'repos/shubamchaudhary/BTech-Project'...
# Cloning into 'repos/BeowulfBKG/Images'...
# Cloning into 'repos/TeclaFernandes/Beecrowd-exerc-cios'...
# Cloning into 'repos/smoonlee1503/Employee_Attrition_ML'...
# Cloning into 'repos/sajadmusavi/exercise'...
# Cloning into 'repos/magic-kch/find_duplicate_by_hash_MD5'...
# Cloning into 'repos/samuuurai/result_script'...
# Cloning into 'repos/ankit848/aa'...
# Cloning into 'repos/Alexey-Arzhannikov/module1hard'...
# Cloning into 'repos/tylerbruno/brain-cancer-classifier'...
# Cloning into 'repos/zakmalik9/Chess'...
# Cloning into 'repos/Ayat6102Mohamed/ML'...
# Cloning into 'repos/GenioustaWiz/multiEmailSend'...
# Cloning into 'repos/Cho01153118/YOLOv9_2'...
# Cloning into 'repos/TheGibler/RL3'...
# Cloning into 'repos/Maxibaldoma/primercrud'...
# Cloning into 'repos/PurpleskellyBoi/test'...
# Cloning into 'repos/DeAdiU/messme-backend'...
# Cloning into 'repos/nnethercott/simple-ml-api'...
# Cloning into 'repos/faridhaavasi/Api_SocialNetwork'...
# Cloning into 'repos/rgstools/Method-facebook'...
# Cloning into 'repos/ibodovmuhammad/home-task'...
# Cloning into 'repos/pataballapravallika/code'...
# Cloning into 'repos/Vivekroy286/BeMyEye'...
# Cloning into 'repos/TatianaSnisarenko/goit-algo-hw-06'...
# Cloning into 'repos/Riyaa22/customer-segmentation-project'...
# Cloning into 'repos/testuser7/aqr_mbn_tool'...
# Cloning into 'repos/Yoax/yCal'...
# Cloning into 'repos/grecheskiy/Grate_work'...
# Cloning into 'repos/andreydedey/Gerenciamento-de-Mercearia'...
# Cloning into 'repos/garfix/richard'...
# Cloning into 'repos/Wirepullerrr/Gaussian-Elimination'...
# Cloning into 'repos/RailGiz/MathStat'...
# Cloning into 'repos/Chupa14142/goit-algo-hw-05'...
# Cloning into 'repos/mikhailkutuzov0/django-easy-CRM'...
# Cloning into 'repos/DanielSkullMaker/DiffusionPromptHub'...
# Cloning into 'repos/dharmendra23101/python-finding-shortest-distance'...
# Cloning into 'repos/wnieva/client_prj'...
# Cloning into 'repos/Jemz123/Newspaper-Summarizer'...
# Cloning into 'repos/bukzor/torn'...
# Cloning into 'repos/IgorGrach0/snake'...
# Cloning into 'repos/kchemorion/refactor'...
# Cloning into 'repos/Abinaya-Ganesh/YouTube_Data_Harvesting_and_Warehousing'...
# Cloning into 'repos/walleser/vetagent'...
# fatal: destination path 'repos/Abinaya-Ganesh/YouTube_Data_Harvesting_and_Warehousing' already exists and is not an empty directory.
# fatal: destination path 'repos/walleser/vetagent' already exists and is not an empty directory.
# Cloning into 'repos/wajih8/jeu-de-mot'...
# Cloning into 'repos/JuliyaGavryushova/django_project'...
# Cloning into 'repos/massodik/sibi'...
# Cloning into 'repos/insper-classroom/24a-bits-lab-9-asm-2-joaorcmr'...
# Cloning into 'repos/VostrikovRoman/Frame'...
# Cloning into 'repos/EslamQadri/predict_images-'...
# Cloning into 'repos/AsmaaShehataa/alx-backend'...
# Cloning into 'repos/HetavP2/BAC'...
# Cloning into 'repos/kt-9-10/stock-news'...
# Cloning into 'repos/sanket6399/spartan-my-companion-backend'...
# Cloning into 'repos/Jeet18t/Image-Detection-Powerpoint-Controller'...
# Cloning into 'repos/Aiaiaisha/tkinterprojects'...
# Cloning into 'repos/devffery/OnlineStore'...
# Cloning into 'repos/RozinaRazzak/Docker'...
# Cloning into 'repos/todiane/mysite'...
# Cloning into 'repos/KalilRamos/Pre-processamento-de-Dados-MassGIS-Data-Public-Water-Supplies'...
# Cloning into 'repos/AbChatterjee04/Python-Projects'...
# Cloning into 'repos/NataliaPerez08/practica-9'...
# Cloning into 'repos/Rushikesh53/news-summarizer'...
# Cloning into 'repos/CIHXPOH/oshibka'...
# Cloning into 'repos/dududacj/dudutrab1'...
# Cloning into 'repos/dkenes/Flower_Classification_Project'...
# Cloning into 'repos/Sudhankd/DASS_bonus_assgn'...
# Cloning into 'repos/signebedi/surreal-health'...
# Cloning into 'repos/tabrizgulmammadov/anpr-data-warehouse'...
# Cloning into 'repos/Chrisi2209/HearYourself'...
# Cloning into 'repos/abhayparmar2612/python_general'...
# Cloning into 'repos/theSuriya/RAG-LLAMA-INDEX'...
# Cloning into 'repos/mrhxx/PlayDL'...
# Cloning into 'repos/Aleksey1975/24-05-selfedu'...
# Cloning into 'repos/dhupianishant/Leetcode-Solutions'...
# Cloning into 'repos/dlgiao/Reusability-project'...
# Cloning into 'repos/lukitos777/CLI-programm'...
# Cloning into 'repos/FranciscoERodrigues/Python---Exercicios'...
# Cloning into 'repos/tderwedu/codecademy'...
# Cloning into 'repos/zeluizr/swiss.images.middleware'...
# Updating files: 100% (954/954), done.
# Cloning into 'repos/athish-ns/blockchain'...
# Cloning into 'repos/JaiprakashSahu/Dot-and-Boxes'...
# Cloning into 'repos/Vladislavus1/IMGToSymbolsConvertorBot'...
# Cloning into 'repos/Aaryan-Anand/OpenRocket-Optimizer'...
# Cloning into 'repos/Jooba111/rest-apis-project'...
# Cloning into 'repos/random1106/baum-welch'...
# Cloning into 'repos/Jumpingquasar/recipe-app-api'...
# Cloning into 'repos/Fernando-Utzig/Data-Analysis-for-Little-Lemon'...
# Cloning into 'repos/AMH767/fast'...
# Cloning into 'repos/Siddique-07/Library-Management'...
# Cloning into 'repos/razeenrasheed83/fast-api-crud-operations-with-db'...
# Cloning into 'repos/Malikamir6691/A8'...
# Cloning into 'repos/techGuy008/AirBnB_clone_v4'...
# Cloning into 'repos/OscarLau109/seem3650project'...
# Cloning into 'repos/OlexandrTsubera/movie_review'...
# Cloning into 'repos/Bogachan-Bakirhan/ders6odev'...
# Cloning into 'repos/Sublustrum007ru/Excample1'...
# Cloning into 'repos/mightcoding/kodland'...
# Cloning into 'repos/MarossC/StellkaNastroje'...
# Cloning into 'repos/char500/Python_Experiments'...
# Cloning into 'repos/hymalatha2003/basic-main'...
# Cloning into 'repos/Sharky1507/Handling-Imbalanced-Data'...
# fatal: destination path 'repos/Sharky1507/Handling-Imbalanced-Data' already exists and is not an empty directory.
# Cloning into 'repos/vishnudevans/python'...
# Cloning into 'repos/Yomaruichi/Hand-Sign-Detection-Device-For-Raspberry-Pi'...
# Cloning into 'repos/jrfk/python-monthly-topic-cli'...
# Cloning into 'repos/sunnymoon1314/amazon-sagemaker-cicd'...
# Cloning into 'repos/Amr1997/studio_back'...
# Cloning into 'repos/cgpeanut/pytorch_examples'...
# Cloning into 'repos/me-hapi/python_training'...
# Cloning into 'repos/ktechnicalguftugu/TCS-LSEG-Technical-Challenge'...
# Cloning into 'repos/amirf147/kaldi-dragonfly-rules'...
# Cloning into 'repos/blinkonce/Duckgrabber_2000'...
# Cloning into 'repos/jishnuntvl/chatapp'...
# Cloning into 'repos/frameton/total-perspective-vortex'...
# Cloning into 'repos/KushalSedhai/DjRest-Login_resgiter_Searching_filtering'...
# Cloning into 'repos/sandeepkiran007/turtle-crossing-game'...
# Cloning into 'repos/bojevilya/Hw4_1'...
# Cloning into 'repos/Efarinyes/binary-search-tree'...
# Cloning into 'repos/prathaya135/Cloud-Computing'...
# Cloning into 'repos/Arvindpatel9200/sunday'...
# Cloning into 'repos/EnricoMendez/pose_estimation'...
# Cloning into 'repos/niktkin/tracklist_parser'...
# Cloning into 'repos/AI-Gallery-Genie/sd-gal-gen'...
# Cloning into 'repos/elliobu1000/KK-AD_Repo'...
# Cloning into 'repos/iliusa77/hello-world-python'...
# Cloning into 'repos/JanCwik1/FakeNewsClassifier'...
# Cloning into 'repos/josecegra/streaming-project'...
# Cloning into 'repos/ShivaniParekh/ML-Project'...
# Cloning into 'repos/St1ckyF0Xx/OOP'...
# Cloning into 'repos/aidan-1227/project-group02'...
# Cloning into 'repos/shelendergp/Qubit_multimode_fit'...
# Cloning into 'repos/Renatazip/leo-web-app'...
# Cloning into 'repos/ElmeriKivipato/Hello2'...
# Cloning into 'repos/xEdison/Bot'...
# Cloning into 'repos/NikBel3476/evacuation-gui-iced'...
# Cloning into 'repos/RonSez/ecobot'...
# Cloning into 'repos/SimoneMozzaia/hundred_days'...
# Cloning into 'repos/Aliosa06/studentu-registravimo-sistema'...
# Cloning into 'repos/JadhavPri/TestPlaywrightProject'...
# Cloning into 'repos/hridoy1000/ThreatScan-Strengthening-Website-Security-with-Predictive-Analytics-Using-Machine-Learning-Model'...
# Cloning into 'repos/charith3903/Machine-Learning-course-code'...
# Cloning into 'repos/pazelisha/rotmg-trader-scraper'...
# Cloning into 'repos/DanaFink/antiVirus'...
# Cloning into 'repos/MohamedNour1452/Car_Dashboard'...
# Cloning into 'repos/rahulnobcoder/TUMOR_MARGIN_TRACING'...
# Cloning into 'repos/Nagi-ovo/Orallama'...
# Cloning into 'repos/FilipeHSAraujo/DIO_Desavio_Felipao'...
# Cloning into 'repos/query-jeremy/ocsf-compat'...
# Cloning into 'repos/shegezzy/Lead-Capture-App'...
# Cloning into 'repos/Cyb3rKotl3Ta/CI-CD'...
# Cloning into 'repos/yassine-bouassida/AlmaazApi'...
# Cloning into 'repos/chiarafi/RobotWalkCircle-LeetCode'...
# Cloning into 'repos/Lika-B96/Task_11.2'...
# Cloning into 'repos/Pradeep-manoharan/Transformer'...
# Cloning into 'repos/MariaPanova/ping_pong'...
# Cloning into 'repos/void0895/catizen'...
# Cloning into 'repos/FelixKorirr/alx-backend'...
# Cloning into 'repos/Fustix/m2l1'...
# Cloning into 'repos/VincentPit/Sudoku'...
# Cloning into 'repos/lucasclx/Pyhton-DIO'...
# Cloning into 'repos/quynhanhpn/bt4'...
# fatal: destination path 'repos/quynhanhpn/bt4' already exists and is not an empty directory.
# Cloning into 'repos/Ali-awesome/final_py_oop'...
# Cloning into 'repos/CarolinaMoran03/S6-TRABAJO-DE-INVESTIGACI-N_1'...
# Cloning into 'repos/adi-devv/API-Usages'...
# Cloning into 'repos/miltonbarroca/RogueLike'...
# Cloning into 'repos/sumeetra12/weather_app'...
# Cloning into 'repos/sv5886/backend_engineering_challenge'...
# Cloning into 'repos/syedfero/Working-with-REST-API'...
# Cloning into 'repos/Radhika02Dherge/LPII'...
# Cloning into 'repos/Abhishekkambleak/Abhimk'...
# Cloning into 'repos/Swayamk2912/currency-converter-'...
# Cloning into 'repos/vanshgoel123/Breakthrough-AI-Powered-Brick-Buster'...
# Cloning into 'repos/MADHUBALASUBRAMANIYAM/PLANT_DISEASE_CLASSIFIER'...
# Cloning into 'repos/BenedekNagy/Moon'...
# Cloning into 'repos/pettk/workshop-api'...
# Cloning into 'repos/Berfin4615/Shooter'...
# Cloning into 'repos/zacharybaca/python-syntax'...
# Cloning into 'repos/Joasjonson/api-cliente'...
# Cloning into 'repos/PIYUSH1585/1'...
# Cloning into 'repos/danorel/aclarel'...
# Cloning into 'repos/iamteja9977/Parallel-Programming'...
# Cloning into 'repos/Pabsthegreat/YOU'...
# Cloning into 'repos/suryakalpana123/-unique-password-generation'...
# Cloning into 'repos/adityazele/flash_cards_app'...
# Cloning into 'repos/VinayChaudhari1996/Reflex-Quote-Webapp'...
# Cloning into 'repos/NosiesPurskalas/KursinisDB_Mk4'...
# Cloning into 'repos/KxFhZ8YJmj6mPrqi/pittProject'...
# Cloning into 'repos/sid-38/wav2vec-malayalam'...
# Cloning into 'repos/TrisenYu/2024-Crypto-Lib'...
# Cloning into 'repos/Quytran1/image-classification-CNN-basic'...
# Cloning into 'repos/JimmySunDance/llm-code-agent'...
# Cloning into 'repos/EatOreo/GrailScrape'...
# Cloning into 'repos/Raody0987/apilesson1-2'...
# Cloning into 'repos/IsmoilSayfitdinov/Youtube-Uploade'...
# Cloning into 'repos/Mansa9769/WatchGood'...
# Cloning into 'repos/mikhail-matrosov/textworks'...
# Cloning into 'repos/Santhoshi0708/Diabetes_Prediction'...
# Cloning into 'repos/ALTA-DE3-FITRIMUSLIKHAH-13041999/Basic-Programming-Part2'...
# Cloning into 'repos/piyandra/PornhubScrapper'...
# Cloning into 'repos/artsyompichinko/webinar_voronka'...
# Cloning into 'repos/RS-master1337/eduphoto'...
# Cloning into 'repos/ArchieASahu/resturant_management'...
# Cloning into 'repos/convenience-tinashe-chibatamoto/simple-company-website-in-python'...
# Cloning into 'repos/LallerH/PyQT_Course'...
# Cloning into 'repos/maksiscool/Pygame_circle_game0'...
# Cloning into 'repos/Nimiates/discord-channel-merge-bot'...
# Cloning into 'repos/foerstd29/tg'...
# Cloning into 'repos/CHAIZY21/frank-wolfe-UE'...
# Cloning into 'repos/brandonalex98/Repositorio-PersonL'...
# Cloning into 'repos/junho2000/MES01_DataUpload'...
# Cloning into 'repos/bdipta01/Final-Exam'...
# Cloning into 'repos/alambertt/100-pandas-troubles'...
# Cloning into 'repos/erezklr/ontop'...
# Cloning into 'repos/EvgenijCherednichenko/5kurs_BD'...
# Cloning into 'repos/Dobiasd/Behagolit'...
# Cloning into 'repos/StarLightFr51/PYT-Downloader'...
# Cloning into 'repos/Bidobelemti/Tarea3_MN'...
# Cloning into 'repos/xi816/skoof-cli'...
# Cloning into 'repos/zeko1654/project.AI'...
# Cloning into 'repos/rahad98/my-todo-app'...
# Cloning into 'repos/Behan-Ravishka/simple-English-to-Sinhala-Translator-using-tkinter'...
# Cloning into 'repos/EnSabahNurX/openvpn-gui'...
# Cloning into 'repos/alvarod91100/Whisper-YT-Audio-Transcription'...
# Cloning into 'repos/jeanfsantos83/python-countryinfo'...
# Cloning into 'repos/DBPFilho/Teste-HTML-PYTHON'...
# Cloning into 'repos/ManarSholi/Book-Django-Project'...
# Cloning into 'repos/itsbasil/iot'...
# Cloning into 'repos/adpadillar/lexical_analyzer-py'...
# Cloning into 'repos/harshalpanchal2000/Compli-Matic'...
# Cloning into 'repos/GeorgSagmeister/Webserver'...
# Cloning into 'repos/mihpavlovic/IEP-project-store-management'...
# Cloning into 'repos/kashyapnathan/FintechLabAssess'...
# Updating files: 100% (32887/32887), done.
# Cloning into 'repos/Zamahell/pruebaTenica'...
# Cloning into 'repos/sesds44ee/dgrrrgffd'...
# Cloning into 'repos/thatcyberboy/subdomains-finalizer'...
# Cloning into 'repos/Veloubie/DeFooocusLite'...
# Cloning into 'repos/nesrinawed/machine-learning-project'...
# Cloning into 'repos/hesammosaffa/Automotive-Price-Prediction-with-Web-Scraping-and-Machine-Learning'...
# Cloning into 'repos/sabri-manai/trader_bot_backend'...
# Cloning into 'repos/Viniccin/Tabela-Periodica'...
# Cloning into 'repos/ashraf7772/Number-Guess-with-Python'...
# Cloning into 'repos/itzsxhan/Food_Detection'...
# Cloning into 'repos/AntonioGabrielBarbosa/dio_bootcamp'...
# Cloning into 'repos/YutaIkki/Calculadora-de-Convers-o'...
# Cloning into 'repos/mnasrimedamine211/document'...
# Cloning into 'repos/berg96/my_wallet_testtask_effectivemobile'...
# Cloning into 'repos/13Belka13/Improving-LLMs-on-underrepresented-Kotlin'...
# Cloning into 'repos/annacmbrito/acervo-pessoal-api'...
# Cloning into 'repos/Dege22/PixQRAPI'...
# Cloning into 'repos/abongiletraeffik/setupDrink'...
# Cloning into 'repos/julianopadua/Cleaner-com-Python'...
# Cloning into 'repos/james20902/connectfour-ai'...
# Cloning into 'repos/drewherron/madlib-syntax'...
# Cloning into 'repos/felipeAGonzalez/Collection'...
# Cloning into 'repos/clys2006/PantryPal'...
# Cloning into 'repos/boleyla1/login'...
# Cloning into 'repos/josse07/juice-machine-oop'...
# Cloning into 'repos/pinguinaje360/tinytasks'...
# Cloning into 'repos/Hydrocallis/solid_color_material'...
# Cloning into 'repos/aiXpertLab/Hallucinations-Reducing'...
# Cloning into 'repos/Mariemaqadar/Pfa--Project'...
# Cloning into 'repos/Fastcrytpos/Challenge-1-Bank-of-Flatiron'...
# Cloning into 'repos/Guidedev223/GDV-HOOKSPAMMER'...
# ...
# Cloning into 'repos/michelleog2351/Intro-To-Python'...
# Cloning into 'repos/lovechants/chess-programming'...
# Updating files: 100% (71/71), done.
# Cloning into 'repos/nicomp42/name-generator-nicomp'...
# fatal: destination path 'repos/Doriasamp/DawgsML' already exists and is not an empty directory.
# Cloning into 'repos/Codingmasster/Company-Employee-Api-Django'...
# fatal: destination path 'repos/AUBAI-ALKHABBAZ/Mapping_TIAGo_lite_Webots' already exists and is not an empty directory.
# Cloning into 'repos/gudnuf/bolt12-covenant-zapper'...
# fatal: destination path 'repos/iurii-umnov/async-parser' already exists and is not an empty directory.
# fatal: destination path 'repos/manavspg4/Quant-Trading-Strategies' already exists and is not an empty directory.
# fatal: destination path 'repos/Mehrafarin77/TCP-chatroom-with-python' already exists and is not an empty directory.
# fatal: destination path 'repos/Junjie529/AWS-election' already exists and is not an empty directory.
# fatal: destination path 'repos/saikothouse/Temp-Mail-Bot' already exists and is not an empty directory.
# Cloning into 'repos/DZXX21/Aray-z'...
# Cloning into 'repos/codename0og/rvc-realtime-voice-changer'...
# fatal: destination path 'repos/DZXX21/Aray-z' already exists and is not an empty directory.
# fatal: destination path 'repos/codename0og/rvc-realtime-voice-changer' already exists and is not an empty directory.
# Cloning into 'repos/Fchery87/timesheet-pdf'...
# fatal: destination path 'repos/Blane187/Blane-RVC-Main' already exists and is not an empty directory.
# fatal: destination path 'repos/Shubham1965/rl-projects' already exists and is not an empty directory.
# fatal: destination path 'repos/Sippaphat/Kiddee-TableQA' already exists and is not an empty directory.
# fatal: destination path 'repos/Gustavo127400/Python' already exists and is not an empty directory.
# Cloning into 'repos/franthemanIT/parlaConANPR'...
# fatal: destination path 'repos/ShubhoEditx/SohiniMusicXPro' already exists and is not an empty directory.
# Cloning into 'repos/lurenbaiqa/LOL-automatically-accepts-matches-and-automatically-reconnects'...
# Cloning into 'repos/Jalyn48595/ISM-480'...
# Cloning into 'repos/mao-code/AIBackend_IntelligentMuseum'...
# Cloning into 'repos/glowworm-YG/2024-'...
# Cloning into 'repos/DivyamSamarwal/Autobot2'...
# Cloning into 'repos/ytrbi/SnakeBeginner'...
# Cloning into 'repos/LaurenzBeck/Skald'...
# Cloning into 'repos/table-harmony/gamingadventures'...
# Cloning into 'repos/shalvapichkhaia/GOAhomeworks'...
# Cloning into 'repos/jeanfsantos83/generating-qrcode-python'...
# Cloning into 'repos/azevedontc/dataPreprocessing'...
# Cloning into 'repos/raphyrenu/SNAKE-GAME'...
# Cloning into 'repos/TRTN3001/compsci_3.3.1'...
# Cloning into 'repos/ssnooopy/spotify-lyric-tool-public'...
# fatal: destination path 'repos/fitri-hy/auto-generate-project-python' already exists and is not an empty directory.
# Cloning into 'repos/Abisheknesa/GCD-'...
# Cloning into 'repos/2375137/12306'...
# Cloning into 'repos/sombra2323/Descargar-Videos-YT'...
# Cloning into 'repos/muralianand12345/chatbot-llamaparse'...
# fatal: destination path 'repos/wert1xxx1/Mafia-Discord-bot' already exists and is not an empty directory.
# Cloning into 'repos/AgentForceTeamOfficial/UA2-WebShop'...
# fatal: destination path 'repos/AgentForceTeamOfficial/UA2-WebShop' already exists and is not an empty directory.
# Cloning into 'repos/DONATE-ARMY/DONATE_X_MUSIC'...
# fatal: destination path 'repos/iamruth143/InternPE' already exists and is not an empty directory.
# Cloning into 'repos/Gesge/ZeroStage_DataCollector'...
# fatal: destination path 'repos/jnotsknab/PokemonShinyBot' already exists and is not an empty directory.
# fatal: destination path 'repos/Hrishikesh19032004/DemandForecasting' already exists and is not an empty directory.
# fatal: destination path 'repos/MemerGamer/TrafficSignRecognitionCNN' already exists and is not an empty directory.
# fatal: destination path 'repos/hnilitskyi/instagram_scraper' already exists and is not an empty directory.
# fatal: destination path 'repos/seanpm2001/LSRT' already exists and is not an empty directory.
# fatal: destination path 'repos/PariBainsla/SnakeGame' already exists and is not an empty directory.
# fatal: destination path 'repos/Junjie529/aws-server-zap' already exists and is not an empty directory.
# Cloning into 'repos/sdmwd/yolov9seg'...
# fatal: destination path 'repos/Frikallo/x-ops' already exists and is not an empty directory.
# fatal: destination path 'repos/Nextcaffe/game_numbers' already exists and is not an empty directory.
# fatal: destination path 'repos/kagura7799/parser-bot' already exists and is not an empty directory.
# fatal: destination path 'repos/sksahid24449/Social-Network-Dataset-Analysis-for-Centrality-Measurement' already exists and is not an empty directory.
# Cloning into 'repos/jeffreyalido/dist_play'...
# fatal: destination path 'repos/Narvasiddhartha/Disaster-Tweet-Classification' already exists and is not an empty directory.
# Cloning into 'repos/cheng-haha/KANs'...
# Cloning into 'repos/theregoesmyeye/blowout'...
# Cloning into 'repos/Bylba4kka/Anekdot_bot'...
# Cloning into 'repos/Actium-Open-Source/aura'...
# Cloning into 'repos/Mandaiya/herosong'...
# Cloning into 'repos/alialtunoglu/Real-Time_Digit_Classification_with_CNN'...
# Cloning into 'repos/jgore077/youtube-livestream-monitor'...
# Cloning into 'repos/swordswind/vosk_stt_app'...
# Cloning into 'repos/RufengSama/oscopilot'...
# Cloning into 'repos/MKSharaf/PyTorch_Implementation'...
# Cloning into 'repos/rapersonal/autodoc'...
# Cloning into 'repos/LautaroSanz/4ctrl'...
# Cloning into 'repos/JseMatamoros/DACOM'...
# fatal: destination path 'repos/fsaza/Crypot-Tools' already exists and is not an empty directory.
# Cloning into 'repos/MironXX555/python'...
# Cloning into 'repos/Tracy-teb/python-rock-paper-scissors-Tracy-teb-main'...
# fatal: destination path 'repos/sqltechnology/Sqltech' already exists and is not an empty directory.
# fatal: destination path 'repos/LucasLisboaDev/CalculatorGUI_Python' already exists and is not an empty directory.
# fatal: destination path 'repos/ferhatyk95/emotional-state-analysis-from-voice' already exists and is not an empty directory.
# Cloning into 'repos/NanDONG2002/20319111-COMP3065-CW'...
# Updating files: 100% (13114/13114), done.
# fatal: destination path 'repos/quinn-sasha/personal_finance_app' already exists and is not an empty directory.
# fatal: destination path 'repos/akki697222/SoundBoard-V1' already exists and is not an empty directory.
# Cloning into 'repos/abdel2000-dply/alx-backend'...
# fatal: destination path 'repos/LevyShaked/Assignments_rep' already exists and is not an empty directory.
# fatal: destination path 'repos/Matvei55/CityHeroes_-git' already exists and is not an empty directory.
# fatal: destination path 'repos/imprasukjain/Code-Pilot' already exists and is not an empty directory.
# fatal: destination path 'repos/brian419/AlgorithmVisualizations' already exists and is not an empty directory.
# Cloning into 'repos/realazthat/mdreftidy'...
# fatal: destination path 'repos/DuckDuckStudio/Just-No-xxx' already exists and is not an empty directory.
# fatal: destination path 'repos/arachnocid/Cryptocurrency-Prediction-Model' already exists and is not an empty directory.
# fatal: destination path 'repos/devinci-it/devinci_rc' already exists and is not an empty directory.
# fatal: destination path 'repos/Harshith1234567/webscraper-using-GPT3.5-langchain-chromaDB' already exists and is not an empty directory.
# Cloning into 'repos/Ijidishurka/bfg'...
# fatal: destination path 'repos/EthanInnit28/NukPack-Tool-Discord-' already exists and is not an empty directory.
# Cloning into 'repos/Killerrajput/Pdf_RAR_ZIP_PASS_CRACKER.py'...
# Cloning into 'repos/blue0x1/mobilemouse-exploit'...
# Cloning into 'repos/wi-ith/blaze_pose'...
# Cloning into 'repos/kypepper/Credit-Score-Prediction'...
# Cloning into 'repos/rabops/ConnectAPI'...
# Cloning into 'repos/Raghava1329/atm_interface'...
# Cloning into 'repos/yangyushuai/OSDDiff'...
# Cloning into 'repos/Jianpinglim/telebot_AI_pdfReader'...
# Cloning into 'repos/avantika2195/laundry-management-system-'...
# Cloning into 'repos/zslzx/SAMFLow'...
# Cloning into 'repos/felix-ch/f3loc'...
# Cloning into 'repos/Thaleeb123/ODD-or-EVEN-'...
# Cloning into 'repos/VictorHSandi/CS5173Project'...
# Cloning into 'repos/Bylba4kka/tasks_parser'...
# fatal: destination path 'repos/Camilly-Alveess/Basic-Natural-Language-Processing' already exists and is not an empty directory.
# fatal: destination path 'repos/Enigma-Soul/EnigmaSoul_Houl' already exists and is not an empty directory.
# fatal: destination path 'repos/XingLanGo/Format_Headers_Dict' already exists and is not an empty directory.
# Cloning into 'repos/boomdrak/proxmox-split-merge-files'...
# fatal: destination path 'repos/ElGreKost/Redundant-Manipulator-Ros' already exists and is not an empty directory.
# Cloning into 'repos/King-s-Knowledge-Graph-Lab/RQV'...
# fatal: destination path 'repos/i-umairkhan/vid2sound' already exists and is not an empty directory.
# fatal: destination path 'repos/swanand203/Stimulate-bouncing-game-using-Pygame' already exists and is not an empty directory.
# fatal: destination path 'repos/BuGmAN12345/book-crawlers' already exists and is not an empty directory.
# Cloning into 'repos/RICH372/RICH-KING-xd-RICH'...
# fatal: destination path 'repos/ufodia/bitcoin_address_generator' already exists and is not an empty directory.
# fatal: destination path 'repos/vishwamm/webapp_objectdetection' already exists and is not an empty directory.
# Cloning into 'repos/aolson078/pygame_demo'...
# fatal: destination path 'repos/vishwamm/webapp_facedetection' already exists and is not an empty directory.
# fatal: destination path 'repos/Sayandeepmaity/neurogest' already exists and is not an empty directory.
# Cloning into 'repos/YoruKiwi/CORVUS'...
# fatal: destination path 'repos/YuvrajSinghSran/Chat-CSV-Using-Langchain-and-OpenAI' already exists and is not an empty directory.
# Cloning into 'repos/dev-perez/bloodborne_notes_bot'...
# fatal: destination path 'repos/hatprof/tg-mass-dm' already exists and is not an empty directory.
# Cloning into 'repos/spardon/finance_dashboard'...
# fatal: destination path 'repos/jggomez/gemini-workshop' already exists and is not an empty directory.
# fatal: destination path 'repos/CeyLabs-Foundation/fin-tracker-backend' already exists and is not an empty directory.
# Cloning into 'repos/sheindel/fw-bsides-2024'...
# Cloning into 'repos/ltcflip/AntiDebug'...
# Cloning into 'repos/Jalyn48595/ISM-370'...
# Cloning into 'repos/ShivgunGaming/file-renamer'...
# Cloning into 'repos/Nexcauzin/Webhook-Dialogflow'...
# Cloning into 'repos/ImSuvodeep/LLM-Based-OS'...
# Cloning into 'repos/curiousjp/ComfyUI-MaskBatchPermutations'...
# Cloning into 'repos/Mustkeem324/Python-Encryption-Tool'...
# Cloning into 'repos/Fanxi1992/ai-literature'...
# Cloning into 'repos/pedrocjdpereira/ThesisProject-PECI'...
# Cloning into 'repos/BerlinNatrolit/Movant-Embedded'...
# Cloning into 'repos/Ebrahimakbari/password-generator'...
# Cloning into 'repos/Gmaster103/Python-SMTP'...
# Cloning into 'repos/jeanfsantos83/extracting-text-from-images'...
# Cloning into 'repos/lpapaspyros/genai_for_good_hackathon'...
# Cloning into 'repos/lavsendahal/generating_radiology_reports'...
# Cloning into 'repos/viveksapkal2793/Socket-Programming-Project'...
# Cloning into 'repos/k4vinliu/ICS2O1-CPT-Punch-Wall-Simulator'...
# Cloning into 'repos/JackMatthew112233/Mymatteo_Puella'...
# fatal: destination path 'repos/brahim77777/Simplex_method_with_php_and_python' already exists and is not an empty directory.
# Cloning into 'repos/SrFluff/pyUnix'...
# Cloning into 'repos/cjliu01/deformable_conv_pytorch'...
# Cloning into 'repos/Thaleeb123/Simple-calculator'...
# fatal: destination path 'repos/VilchisV/metodos' already exists and is not an empty directory.
# Cloning into 'repos/ArnabAdhikar/Face-Detection-System'...
# fatal: destination path 'repos/Jalithc/check_if_updated' already exists and is not an empty directory.
# Cloning into 'repos/Ron12Rom1/MyAI'...
# fatal: destination path 'repos/WojtekCodesToday/rgb-hex-renderer' already exists and is not an empty directory.
# fatal: destination path 'repos/ssapna64/BANKINGPROJECT' already exists and is not an empty directory.
# fatal: destination path 'repos/Amaan9136/vision-xray' already exists and is not an empty directory.
# Cloning into 'repos/AlirezaSaadatmand/Mega_Snake_Game'...
# fatal: destination path 'repos/AndB0ndar/django_mongodb_template' already exists and is not an empty directory.
# fatal: destination path 'repos/pyungjong0314/Embedding-Using-Korean' already exists and is not an empty directory.
# fatal: destination path 'repos/tolm1/-GUI-' already exists and is not an empty directory.
# fatal: destination path 'repos/soglopr/TetrisT' already exists and is not an empty directory.
# fatal: destination path 'repos/qaz-del/inter_demo' already exists and is not an empty directory.
# fatal: destination path 'repos/Dashstrom/pixelize' already exists and is not an empty directory.
# fatal: destination path 'repos/engineerjoe440/phasors' already exists and is not an empty directory.
# fatal: destination path 'repos/silky-modi22/Video-Transcribe-Summarizer' already exists and is not an empty directory.
# fatal: destination path 'repos/AppleBoiy/FlaskPG-dev' already exists and is not an empty directory.
# Cloning into 'repos/hassannihal/ImpactNet'...
# fatal: destination path 'repos/Pawan-079/Movies-Recommendation-System-End-to-end' already exists and is not an empty directory.
# fatal: destination path 'repos/KJ-Script/Sniffer' already exists and is not an empty directory.
# fatal: destination path 'repos/Amadeo-Frontend/Python__TDD-project' already exists and is not an empty directory.
# fatal: destination path 'repos/Tarodictrl/GenshinWishHistory' already exists and is not an empty directory.
# fatal: destination path 'repos/bhart17/robohack24' already exists and is not an empty directory.
# fatal: destination path 'repos/josnin/llama-medical' already exists and is not an empty directory.
# fatal: destination path 'repos/younesbram/chef-roast-me' already exists and is not an empty directory.
# Cloning into 'repos/Akamemz/Identification-of-Political-Ideology'...
# Updating files: 100% (37574/37574), done.
# fatal: destination path 'repos/zxuuuustupid/cifar10' already exists and is not an empty directory.
# fatal: destination path 'repos/Ashleshk/Realtime-Data-Streaming-Data-Engineering-Project' already exists and is not an empty directory.
# Cloning into 'repos/Abdelrahme/Trevorc2_decrypt'...
# Cloning into 'repos/projetosTherion/TherionIPAdapter'...
# Cloning into 'repos/RayPals/Python_Irrlicht_AI_DEMO'...
# Cloning into 'repos/anjana-codes/datafun-01-attr'...
# Cloning into 'repos/rpbrisbane/sqlite-student-mgmt-project'...
# Cloning into 'repos/allhgr/Teste-de-repositorio'...
# Cloning into 'repos/maitha2004/final'...
# Cloning into 'repos/cmathur13/Flash_haskart'...
# Cloning into 'repos/rpbrisbane/app-5-news-api-email'...
# Cloning into 'repos/sminii777/open'...
# Cloning into 'repos/darkalx12/alx-backend-python'...
# Cloning into 'repos/sdhorne/Final2'...
# Cloning into 'repos/rbizh004/pythonProjectzhekai'...
# Cloning into 'repos/BharathSBipin/miniprojectydemo'...
# Cloning into 'repos/RithvikSingh/Python-Dog-Bed-Database'...
# Cloning into 'repos/rpbrisbane/project-OOP-articles'...
# Cloning into 'repos/rpbrisbane/app4-invoice-generation'...
# Cloning into 'repos/rpbrisbane/app9-webcam-detection-app'...
# Cloning into 'repos/anshidnm/Vendor-Management'...
# Cloning into 'repos/nkumardap/homework3'...
# Cloning into 'repos/sindhu372/sindhu_git_learn'...
# Cloning into 'repos/Billionaire-Developer/CSEPC-110'...
# Cloning into 'repos/julioCRV/VSFTPD_PROYECTO'...
# Cloning into 'repos/franz-adam/AI-Trading-Simulator'...
# Cloning into 'repos/LuisJordao98/resolu-o1180'...
# Cloning into 'repos/BridgeCityRobotics/2024_Eclipse_TimeLapse'...
# Cloning into 'repos/satyender52/pythonProject15'...
# Cloning into 'repos/Hasan-mollik/pythonProject2'...
# Cloning into 'repos/muhammadzkralla/alx-backend-python'...
# Cloning into 'repos/abbey-deniro/DailySpark'...
# Cloning into 'repos/Kc212692/Homework_6'...
